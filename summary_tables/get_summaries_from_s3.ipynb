# %%
from get_file_from_s3 import fetch_latest_data

# %%
fetch_latest_data("business-news-sentiments", "news_sentiments_monthly/combined_networks", "monthly_sentiment_summary")
fetch_latest_data("business-news-sentiments", "news_sentiments_monthly/topic_breakdown", "monthly_topics_summary")
# Out:
# ✅ Found file: news_sentiments_monthly/combined_networks/20251216_193247_00241_2bqnu_5e2a10f8-9fba-4cc8-92a0-549ccb812d47.gz
# ⬇️ Download complete.
# 🗃️ Data loaded into DataFrame and saved locally.
# ✅ Found file: news_sentiments_monthly/topic_breakdown/20251216_193211_00223_yc3bm_d379ee98-4322-4bc0-9b66-f4153dbc1880.gz
# ⬇️ Download complete.
# 🗃️ Data loaded into DataFrame and saved locally.
