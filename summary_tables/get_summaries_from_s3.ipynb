# %%
from get_file_from_s3 import fetch_latest_data

# %%
fetch_latest_data("business-news-sentiments", "news_sentiments_monthly/sentiment", "monthly_combined_sentiments")
fetch_latest_data("business-news-sentiments", "news_sentiments_monthly/topic_breakdown", "monthly_topics_brakedown")
# Out:
# ✅ Found file: news_sentiments_monthly/sentiment/monthly_combined_sentiments.csv
# ✅ Found file: news_sentiments_monthly/topic_breakdown/monthly_topic_breakdown.csv
